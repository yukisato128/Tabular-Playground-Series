# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    A    B    A    A    B    D    A    E    C  ...  0.881122  0.421650
# 1   2    B    A    A    A    B    B    A    E    A  ...  0.440011  0.346230
# 2   3    A    A    A    C    B    D    A    B    C  ...  0.914155  0.369602
# 3   4    A    A    A    C    B    D    A    E    G  ...  0.934138  0.578930
# 4   6    A    B    A    A    B    B    A    E    C  ...  0.382600  0.705940
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 1  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 2  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 3  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 4  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743
#
#      target
# 0  6.994023
# 1  8.071256
# 2  5.760456
# 3  7.806457
# ...

# %%
# Basic infromation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      300000 non-null  int64
#  1   cat0    300000 non-null  object
#  2   cat1    300000 non-null  object
#  3   cat2    300000 non-null  object
#  4   cat3    300000 non-null  object
#  5   cat4    300000 non-null  object
#  6   cat5    300000 non-null  object
#  7   cat6    300000 non-null  object
#  8   cat7    300000 non-null  object
#  9   cat8    300000 non-null  object
#  10  cat9    300000 non-null  object
#  11  cont0   300000 non-null  float64
#  12  cont1   300000 non-null  float64
#  13  cont2   300000 non-null  float64
#  14  cont3   300000 non-null  float64
#  15  cont4   300000 non-null  float64
#  16  cont5   300000 non-null  float64
#  17  cont6   300000 non-null  float64
#  18  cont7   300000 non-null  float64
#  19  cont8   300000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id          cont0          cont1          cont2  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   250018.576947       0.524634       0.506649       0.444115
# std    144450.150010       0.204875       0.235269       0.200089
# min         1.000000      -0.093505      -0.055105      -0.060274
# 25%    124772.500000       0.370451       0.352307       0.314121
# 50%    250002.500000       0.492208       0.615156       0.457271
# 75%    375226.500000       0.654793       0.688150       0.554835
# max    499999.000000       1.052666       0.851746       1.017689
#
#                cont3          cont4          cont5          cont6  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.446214       0.455471       0.508337       0.478345
# std         0.238669       0.200695       0.231612       0.192432
# min         0.134760       0.189216      -0.087247       0.043953
# ...

# %% [markdown]
# ### Prepare X and y

# %%
X_data = df.drop(['id', 'target', 'cat0', 'cat1', 'cat2','cat3','cat4','cat5','cat6','cat7','cat8','cat9'], axis=1)
X_data.head()
# Out:
#       cont0     cont1     cont2     cont3     cont4     cont5     cont6  \
# 0  0.923191  0.684968  0.124454  0.217886  0.281421  0.881122  0.421650
# 1  0.437627  0.014213  0.357438  0.846127  0.282354  0.440011  0.346230
# 2  0.732209  0.760122  0.454644  0.812990  0.293756  0.914155  0.369602
# 3  0.705142  0.771678  0.153735  0.732893  0.769785  0.934138  0.578930
# 4  0.486063  0.639349  0.496212  0.354186  0.279105  0.382600  0.705940
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13
# 0  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 1  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 2  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 3  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 4  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743

# %%
y_data = df['target']
y_data.head()
# Out:
# 0    6.994023
# 1    8.071256
# 2    5.760456
# 3    7.806457
# 4    6.868974
# Name: target, dtype: float64

# %% [markdown]
# ### Split data into  training and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.30, random_state=1)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regr.score(X_test, y_test)
# Out:
# 0.010526284713466616

# %% [markdown]
# ### RMSE

# %%
y_hat = regr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, y_hat))
# Out:
# 0.8836937488302852

# %% [markdown]
# ## Create Dummy- 1

# %%
df_2 = pd.read_csv('train.csv')
df_2.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    A    B    A    A    B    D    A    E    C  ...  0.881122  0.421650
# 1   2    B    A    A    A    B    B    A    E    A  ...  0.440011  0.346230
# 2   3    A    A    A    C    B    D    A    B    C  ...  0.914155  0.369602
# 3   4    A    A    A    C    B    D    A    E    G  ...  0.934138  0.578930
# 4   6    A    B    A    A    B    B    A    E    C  ...  0.382600  0.705940
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 1  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 2  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 3  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 4  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743
#
#      target
# 0  6.994023
# 1  8.071256
# 2  5.760456
# 3  7.806457
# ...

# %% [markdown]
# ### Count each cat's unique num

# %%
for n in range(10):
    print('-cat'+str(n))
    print(df_2['cat'+str(n)].value_counts())
    print('-----------')
# Out:
# -cat0
# A    281471
# B     18529
# Name: cat0, dtype: int64
# -----------
# -cat1
# A    162678
# B    137322
# Name: cat1, dtype: int64
# -----------
# -cat2
# A    276551
# B     23449
# Name: cat2, dtype: int64
# -----------
# -cat3
# C    183752
# A    104464
# D     11174
# B       610
# Name: cat3, dtype: int64
# -----------
# -cat4
# B    297373
# A      1241
# C       767
# D       619
# Name: cat4, dtype: int64
# -----------
# -cat5
# B    149208
# D    135151
# C     11763
# A      3878
# Name: cat5, dtype: int64
# -----------
# -cat6
# A    292643
# B      6344
# C       809
# D       147
# I        24
# E        19
# H        11
# G         3
# Name: cat6, dtype: int64
# -----------
# -cat7
# E    267631
# D     24356
# B      5750
# G      1961
# F       279
# A        14
# C         6
# I         3
# Name: cat7, dtype: int64
# -----------
# -cat8
# C    121054
# E     94616
# G     42195
# A     37878
# D      3694
# F       549
# B        14
# ...

# %%
X_data_2 = df_2.drop(['id', 'target','cat4','cat5','cat6','cat7','cat8','cat9'], axis=1)
X_data_2.head()
# Out:
#   cat0 cat1 cat2 cat3     cont0     cont1     cont2     cont3     cont4  \
# 0    A    B    A    A  0.923191  0.684968  0.124454  0.217886  0.281421
# 1    B    A    A    A  0.437627  0.014213  0.357438  0.846127  0.282354
# 2    A    A    A    C  0.732209  0.760122  0.454644  0.812990  0.293756
# 3    A    A    A    C  0.705142  0.771678  0.153735  0.732893  0.769785
# 4    A    B    A    A  0.486063  0.639349  0.496212  0.354186  0.279105
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.881122  0.421650  0.741413  0.895799  0.802461  0.724417  0.701915
# 1  0.440011  0.346230  0.278495  0.593413  0.546056  0.613252  0.741289
# 2  0.914155  0.369602  0.832564  0.865620  0.825251  0.264104  0.695561
# 3  0.934138  0.578930  0.407313  0.868099  0.794402  0.494269  0.698125
# 4  0.382600  0.705940  0.325193  0.440967  0.462146  0.724447  0.683073
#
#      cont12    cont13
# 0  0.877618  0.719903
# 1  0.326679  0.808464
# 2  0.869133  0.828352
# ...

# %%
for n in range(4):
    X_data_2 = pd.get_dummies(X_data_2, columns=['cat'+str(n)], drop_first=True)
print('done')
# Out:
# done

# %%
X_data_2['cat0_B'].value_counts()
# Out:
# 0    281471
# 1     18529
# Name: cat0_B, dtype: int64

# %%
X_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 20 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cont0   300000 non-null  float64
#  1   cont1   300000 non-null  float64
#  2   cont2   300000 non-null  float64
#  3   cont3   300000 non-null  float64
#  4   cont4   300000 non-null  float64
#  5   cont5   300000 non-null  float64
#  6   cont6   300000 non-null  float64
#  7   cont7   300000 non-null  float64
#  8   cont8   300000 non-null  float64
#  9   cont9   300000 non-null  float64
#  10  cont10  300000 non-null  float64
#  11  cont11  300000 non-null  float64
#  12  cont12  300000 non-null  float64
#  13  cont13  300000 non-null  float64
#  14  cat0_B  300000 non-null  uint8
#  15  cat1_B  300000 non-null  uint8
#  16  cat2_B  300000 non-null  uint8
#  17  cat3_B  300000 non-null  uint8
#  18  cat3_C  300000 non-null  uint8
#  19  cat3_D  300000 non-null  uint8
# ...

# %% [markdown]
# ###  Split data into  training and test

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_data_2, y_data, test_size=0.30, random_state=1)

# %% [markdown]
# ### Linear Regression

# %%
regr_2 = linear_model.LinearRegression()
regr_2.fit(X_train_2, y_train_2)
# Out:
# LinearRegression()

# %%
regr_2.score(X_test_2, y_test_2)
# Out:
# 0.03988809928638393

# %% [markdown]
# ### RMSE

# %%
y_hat_2 = regr_2.predict(X_test_2)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test_2, y_hat_2))
# Out:
# 0.8704835697793203

# %% [markdown]
# ## Create Dummy -2

# %%
df_3 = pd.read_csv('train.csv')
df_3.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    A    B    A    A    B    D    A    E    C  ...  0.881122  0.421650
# 1   2    B    A    A    A    B    B    A    E    A  ...  0.440011  0.346230
# 2   3    A    A    A    C    B    D    A    B    C  ...  0.914155  0.369602
# 3   4    A    A    A    C    B    D    A    E    G  ...  0.934138  0.578930
# 4   6    A    B    A    A    B    B    A    E    C  ...  0.382600  0.705940
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 1  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 2  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 3  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 4  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743
#
#      target
# 0  6.994023
# 1  8.071256
# 2  5.760456
# 3  7.806457
# ...

# %%
X_data_3 = df_2.drop(['id', 'target'], axis=1)
X_data_3.head()
# Out:
#   cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont4     cont5  \
# 0    A    B    A    A    B    D    A    E    C    I  ...  0.281421  0.881122
# 1    B    A    A    A    B    B    A    E    A    F  ...  0.282354  0.440011
# 2    A    A    A    C    B    D    A    B    C    N  ...  0.293756  0.914155
# 3    A    A    A    C    B    D    A    E    G    K  ...  0.769785  0.934138
# 4    A    B    A    A    B    B    A    E    C    F  ...  0.279105  0.382600
#
#       cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# 0  0.421650  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618
# 1  0.346230  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679
# 2  0.369602  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133
# 3  0.578930  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799
# 4  0.705940  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457
#
#      cont13
# 0  0.719903
# 1  0.808464
# 2  0.828352
# 3  0.614766
# ...

# %%
for n in range(10):
    X_data_3 = pd.get_dummies(X_data_3, columns=['cat'+str(n)], drop_first=True)
print('done')
# Out:
# done

# %%
X_data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 60 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cont0   300000 non-null  float64
#  1   cont1   300000 non-null  float64
#  2   cont2   300000 non-null  float64
#  3   cont3   300000 non-null  float64
#  4   cont4   300000 non-null  float64
#  5   cont5   300000 non-null  float64
#  6   cont6   300000 non-null  float64
#  7   cont7   300000 non-null  float64
#  8   cont8   300000 non-null  float64
#  9   cont9   300000 non-null  float64
#  10  cont10  300000 non-null  float64
#  11  cont11  300000 non-null  float64
#  12  cont12  300000 non-null  float64
#  13  cont13  300000 non-null  float64
#  14  cat0_B  300000 non-null  uint8
#  15  cat1_B  300000 non-null  uint8
#  16  cat2_B  300000 non-null  uint8
#  17  cat3_B  300000 non-null  uint8
#  18  cat3_C  300000 non-null  uint8
#  19  cat3_D  300000 non-null  uint8
# ...

# %% [markdown]
# ###  Split data into  training and test

# %%
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_data_3, y_data, test_size=0.30, random_state=1)

# %% [markdown]
# ### Linear Regression

# %%
regr_3 = linear_model.LinearRegression()
regr_3.fit(X_train_3, y_train_3)
# Out:
# LinearRegression()

# %%
regr_3.score(X_test_3, y_test_3)
# Out:
# 0.054257657596583075

# %% [markdown]
# ### RMSE

# %%
y_hat_3 = regr_3.predict(X_test_3)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test_3, y_hat_3))
# Out:
# 0.8639449464826138
